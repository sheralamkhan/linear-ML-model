# %%
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Data normalization
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# One-hot encode labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
plt.imshow(x_train[2000])
plt.title(f'Label: {y_train[0].argmax()}')
plt.axis('off')  # Hides axis ticks
plt.show()

# %%
import matplotlib.pyplot as plt

# Display 25 random images from the training set
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])  # Show the image
    plt.xlabel(f'Label: {y_train[i].argmax()}')  # Show the label (one-hot encoded to integer)
plt.show()

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)
train_datagen.fit(x_train)

# %%
# Model architecture
model = Sequential()

# First block with increased filters
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

# Second block
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

# Third block
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

# Fully connected layers
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
# Compile the model with a slightly lower learning rate
optimizer = Adam(learning_rate=0.00005)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-6)

# Model summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)                   │ (None, 32, 32, 128)         │           3,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_16               │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 32, 32, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_17               │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 16, 16, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_18               │ (None, 16, 16, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 16, 16, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_19               │ (None, 16, 16, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 8, 8, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_20               │ (None, 8, 8, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_21               │ (None, 8, 8, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 512)                 │       4,194,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_22               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_23               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,915,338 (34.01 MB)
#  Trainable params: 8,910,218 (33.99 MB)
#  Non-trainable params: 5,120 (20.00 KB)

# %%
# Train the model with a smaller batch size
history = model.fit(
    train_datagen.flow(x_train, y_train, batch_size=32),
    epochs=115,
    validation_data=(x_test, y_test),
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 44ms/step - accuracy: 0.1880 - loss: 3.0304 - val_accuracy: 0.3733 - val_loss: 1.7695 - learning_rate: 5.0000e-05
# Epoch 2/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 36ms/step - accuracy: 0.2991 - loss: 2.2186 - val_accuracy: 0.3872 - val_loss: 1.8203 - learning_rate: 5.0000e-05
# Epoch 3/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 37ms/step - accuracy: 0.3539 - loss: 1.9547 - val_accuracy: 0.3839 - val_loss: 1.9309 - learning_rate: 5.0000e-05
# Epoch 4/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 37ms/step - accuracy: 0.4019 - loss: 1.7461 - val_accuracy: 0.3948 - val_loss: 2.0434 - learning_rate: 5.0000e-05
# Epoch 5/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 36ms/step - accuracy: 0.4456 - loss: 1.6002 - val_accuracy: 0.4200 - val_loss: 2.0292 - learning_rate: 5.0000e-05
# Epoch 6/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - accuracy: 0.4975 - loss: 1.4376 - val_accuracy: 0.5063 - val_loss: 1.5539 - learning_rate: 5.0000e-05
# Epoch 7/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 37ms/step - accuracy: 0.5295 - loss: 1.3385 - val_accuracy: 0.5127 - val_loss: 1.6288 - learning_rate: 5.0000e-05
# Epoch 8/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 37ms/step - accuracy: 0.5618 - loss: 1.2399 - val_accuracy: 0.5906 - val_loss: 1.2342 - learning_rate: 5.0000e-05
# Epoch 9/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 37ms/step - accuracy: 0.5951 - loss: 1.1420 - val_accuracy: 0.6218 - val_loss: 1.1123 - learning_rate: 5.0000e-05
# Epoch 10/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.6239 - loss: 1.0731 - val_accuracy: 0.6346 - val_loss: 1.1269 - learning_rate: 5.0000e-05
# Epoch 11/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 84s 37ms/step - accuracy: 0.6402 - loss: 1.0250 - val_accuracy: 0.6684 - val_loss: 0.9825 - learning_rate: 5.0000e-05
# Epoch 12/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 58s 37ms/step - accuracy: 0.6596 - loss: 0.9722 - val_accuracy: 0.7029 - val_loss: 0.8678 - learning_rate: 5.0000e-05
# Epoch 13/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 58s 37ms/step - accuracy: 0.6804 - loss: 0.9154 - val_accuracy: 0.6732 - val_loss: 0.9849 - learning_rate: 5.0000e-05
# Epoch 14/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 37ms/step - accuracy: 0.6999 - loss: 0.8685 - val_accuracy: 0.7211 - val_loss: 0.8402 - learning_rate: 5.0000e-05
# Epoch 15/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 37ms/step - accuracy: 0.7122 - loss: 0.8286 - val_accuracy: 0.7525 - val_loss: 0.7441 - learning_rate: 5.0000e-05
# Epoch 16/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 37ms/step - accuracy: 0.7236 - loss: 0.7938 - val_accuracy: 0.7594 - val_loss: 0.7067 - learning_rate: 5.0000e-05
# Epoch 17/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 59s 37ms/step - accuracy: 0.7398 - loss: 0.7546 - val_accuracy: 0.7618 - val_loss: 0.6987 - learning_rate: 5.0000e-05
# Epoch 18/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 36ms/step - accuracy: 0.7469 - loss: 0.7399 - val_accuracy: 0.7659 - val_loss: 0.7042 - learning_rate: 5.0000e-05
# Epoch 19/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 37ms/step - accuracy: 0.7593 - loss: 0.7082 - val_accuracy: 0.7579 - val_loss: 0.7339 - learning_rate: 5.0000e-05
# Epoch 20/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 36ms/step - accuracy: 0.7655 - loss: 0.6838 - val_accuracy: 0.7914 - val_loss: 0.6206 - learning_rate: 5.0000e-05
# Epoch 21/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 58s 37ms/step - accuracy: 0.7775 - loss: 0.6553 - val_accuracy: 0.7929 - val_loss: 0.6404 - learning_rate: 5.0000e-05
# Epoch 22/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 37ms/step - accuracy: 0.7846 - loss: 0.6334 - val_accuracy: 0.8087 - val_loss: 0.5745 - learning_rate: 5.0000e-05
# Epoch 23/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.7887 - loss: 0.6189 - val_accuracy: 0.8189 - val_loss: 0.5324 - learning_rate: 5.0000e-05
# Epoch 24/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.7964 - loss: 0.5925 - val_accuracy: 0.7985 - val_loss: 0.6298 - learning_rate: 5.0000e-05
# Epoch 25/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8021 - loss: 0.5870 - val_accuracy: 0.8316 - val_loss: 0.5141 - learning_rate: 5.0000e-05
# Epoch 26/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8150 - loss: 0.5532 - val_accuracy: 0.8210 - val_loss: 0.5456 - learning_rate: 5.0000e-05
# Epoch 27/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - accuracy: 0.8155 - loss: 0.5529 - val_accuracy: 0.8350 - val_loss: 0.5041 - learning_rate: 5.0000e-05
# Epoch 28/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 58s 37ms/step - accuracy: 0.8160 - loss: 0.5370 - val_accuracy: 0.8379 - val_loss: 0.4848 - learning_rate: 5.0000e-05
# Epoch 29/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8226 - loss: 0.5246 - val_accuracy: 0.8400 - val_loss: 0.4783 - learning_rate: 5.0000e-05
# Epoch 30/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8289 - loss: 0.5125 - val_accuracy: 0.8437 - val_loss: 0.4711 - learning_rate: 5.0000e-05
# Epoch 31/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.8312 - loss: 0.4999 - val_accuracy: 0.8403 - val_loss: 0.4991 - learning_rate: 5.0000e-05
# Epoch 32/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8365 - loss: 0.4791 - val_accuracy: 0.8535 - val_loss: 0.4389 - learning_rate: 5.0000e-05
# Epoch 33/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.8393 - loss: 0.4759 - val_accuracy: 0.8579 - val_loss: 0.4354 - learning_rate: 5.0000e-05
# Epoch 34/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 84s 37ms/step - accuracy: 0.8440 - loss: 0.4637 - val_accuracy: 0.8526 - val_loss: 0.4471 - learning_rate: 5.0000e-05
# Epoch 35/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 35ms/step - accuracy: 0.8464 - loss: 0.4603 - val_accuracy: 0.8622 - val_loss: 0.4203 - learning_rate: 5.0000e-05
# Epoch 36/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 36ms/step - accuracy: 0.8461 - loss: 0.4572 - val_accuracy: 0.8619 - val_loss: 0.4266 - learning_rate: 5.0000e-05
# Epoch 37/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 36ms/step - accuracy: 0.8519 - loss: 0.4410 - val_accuracy: 0.8547 - val_loss: 0.4448 - learning_rate: 5.0000e-05
# Epoch 38/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 37ms/step - accuracy: 0.8577 - loss: 0.4273 - val_accuracy: 0.8670 - val_loss: 0.3988 - learning_rate: 5.0000e-05
# Epoch 39/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 35ms/step - accuracy: 0.8514 - loss: 0.4387 - val_accuracy: 0.8631 - val_loss: 0.4254 - learning_rate: 5.0000e-05
# Epoch 40/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8600 - loss: 0.4134 - val_accuracy: 0.8708 - val_loss: 0.3921 - learning_rate: 5.0000e-05
# Epoch 41/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - accuracy: 0.8582 - loss: 0.4198 - val_accuracy: 0.8749 - val_loss: 0.3877 - learning_rate: 5.0000e-05
# Epoch 42/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.8618 - loss: 0.4078 - val_accuracy: 0.8662 - val_loss: 0.4167 - learning_rate: 5.0000e-05
# Epoch 43/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8641 - loss: 0.3992 - val_accuracy: 0.8798 - val_loss: 0.3690 - learning_rate: 5.0000e-05
# Epoch 44/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.8683 - loss: 0.3851 - val_accuracy: 0.8746 - val_loss: 0.3716 - learning_rate: 5.0000e-05
# Epoch 45/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - accuracy: 0.8729 - loss: 0.3817 - val_accuracy: 0.8795 - val_loss: 0.3648 - learning_rate: 5.0000e-05
# Epoch 46/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.8720 - loss: 0.3792 - val_accuracy: 0.8761 - val_loss: 0.3884 - learning_rate: 5.0000e-05
# Epoch 47/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.8774 - loss: 0.3676 - val_accuracy: 0.8765 - val_loss: 0.3885 - learning_rate: 5.0000e-05
# Epoch 48/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.8735 - loss: 0.3757 - val_accuracy: 0.8681 - val_loss: 0.4271 - learning_rate: 5.0000e-05
# Epoch 49/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.8791 - loss: 0.3559 - val_accuracy: 0.8903 - val_loss: 0.3396 - learning_rate: 5.0000e-05
# Epoch 50/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 35ms/step - accuracy: 0.8805 - loss: 0.3495 - val_accuracy: 0.8819 - val_loss: 0.3672 - learning_rate: 5.0000e-05
# Epoch 51/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.8842 - loss: 0.3457 - val_accuracy: 0.8859 - val_loss: 0.3434 - learning_rate: 5.0000e-05
# Epoch 52/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 36ms/step - accuracy: 0.8802 - loss: 0.3516 - val_accuracy: 0.8801 - val_loss: 0.3707 - learning_rate: 5.0000e-05
# Epoch 53/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 54s 34ms/step - accuracy: 0.8841 - loss: 0.3451 - val_accuracy: 0.8789 - val_loss: 0.3865 - learning_rate: 5.0000e-05
# Epoch 54/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 84s 36ms/step - accuracy: 0.8884 - loss: 0.3323 - val_accuracy: 0.8828 - val_loss: 0.3620 - learning_rate: 5.0000e-05
# Epoch 55/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.8897 - loss: 0.3286 - val_accuracy: 0.8903 - val_loss: 0.3363 - learning_rate: 5.0000e-05
# Epoch 56/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.8925 - loss: 0.3169 - val_accuracy: 0.8889 - val_loss: 0.3524 - learning_rate: 5.0000e-05
# Epoch 57/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.8940 - loss: 0.3174 - val_accuracy: 0.8807 - val_loss: 0.3811 - learning_rate: 5.0000e-05
# Epoch 58/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8922 - loss: 0.3152 - val_accuracy: 0.8930 - val_loss: 0.3387 - learning_rate: 5.0000e-05
# Epoch 59/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8930 - loss: 0.3176 - val_accuracy: 0.8863 - val_loss: 0.3761 - learning_rate: 5.0000e-05
# Epoch 60/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 35ms/step - accuracy: 0.8943 - loss: 0.3090 - val_accuracy: 0.8921 - val_loss: 0.3351 - learning_rate: 5.0000e-05
# Epoch 61/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.8995 - loss: 0.2956 - val_accuracy: 0.8882 - val_loss: 0.3559 - learning_rate: 5.0000e-05
# Epoch 62/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 84s 36ms/step - accuracy: 0.8983 - loss: 0.3014 - val_accuracy: 0.8887 - val_loss: 0.3626 - learning_rate: 5.0000e-05
# Epoch 63/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.9032 - loss: 0.2880 - val_accuracy: 0.8968 - val_loss: 0.3321 - learning_rate: 5.0000e-05
# Epoch 64/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8998 - loss: 0.2940 - val_accuracy: 0.8907 - val_loss: 0.3503 - learning_rate: 5.0000e-05
# Epoch 65/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.9028 - loss: 0.2846 - val_accuracy: 0.8955 - val_loss: 0.3272 - learning_rate: 5.0000e-05
# Epoch 66/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.9026 - loss: 0.2877 - val_accuracy: 0.8833 - val_loss: 0.3908 - learning_rate: 5.0000e-05
# Epoch 67/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 36ms/step - accuracy: 0.9051 - loss: 0.2841 - val_accuracy: 0.8810 - val_loss: 0.3801 - learning_rate: 5.0000e-05
# Epoch 68/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.9094 - loss: 0.2637 - val_accuracy: 0.8849 - val_loss: 0.3782 - learning_rate: 5.0000e-05
# Epoch 69/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.9055 - loss: 0.2794 - val_accuracy: 0.9029 - val_loss: 0.3037 - learning_rate: 5.0000e-05
# Epoch 70/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.9098 - loss: 0.2668 - val_accuracy: 0.8954 - val_loss: 0.3337 - learning_rate: 5.0000e-05
# Epoch 71/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.9097 - loss: 0.2696 - val_accuracy: 0.8827 - val_loss: 0.3888 - learning_rate: 5.0000e-05
# Epoch 72/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.9128 - loss: 0.2614 - val_accuracy: 0.8974 - val_loss: 0.3376 - learning_rate: 5.0000e-05
# Epoch 73/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.9081 - loss: 0.2682 - val_accuracy: 0.8912 - val_loss: 0.3625 - learning_rate: 5.0000e-05
# Epoch 74/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.9138 - loss: 0.2625 - val_accuracy: 0.8990 - val_loss: 0.3222 - learning_rate: 5.0000e-05
# Epoch 75/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.9172 - loss: 0.2486 - val_accuracy: 0.8894 - val_loss: 0.3666 - learning_rate: 5.0000e-05
# Epoch 76/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.9135 - loss: 0.2562 - val_accuracy: 0.8966 - val_loss: 0.3256 - learning_rate: 5.0000e-05
# Epoch 77/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.9177 - loss: 0.2413 - val_accuracy: 0.9025 - val_loss: 0.3249 - learning_rate: 2.5000e-05
# Epoch 78/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 36ms/step - accuracy: 0.9247 - loss: 0.2236 - val_accuracy: 0.9012 - val_loss: 0.3326 - learning_rate: 2.5000e-05
# Epoch 79/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - accuracy: 0.9247 - loss: 0.2194 - val_accuracy: 0.9045 - val_loss: 0.3116 - learning_rate: 2.5000e-05
# Epoch 80/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.9251 - loss: 0.2221 - val_accuracy: 0.9086 - val_loss: 0.3041 - learning_rate: 2.5000e-05
# Epoch 81/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.9254 - loss: 0.2155 - val_accuracy: 0.9058 - val_loss: 0.3142 - learning_rate: 2.5000e-05
# Epoch 82/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.9287 - loss: 0.2155 - val_accuracy: 0.9070 - val_loss: 0.3090 - learning_rate: 2.5000e-05
# Epoch 83/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.9285 - loss: 0.2118 - val_accuracy: 0.8964 - val_loss: 0.3414 - learning_rate: 2.5000e-05
# Epoch 84/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.9323 - loss: 0.2017 - val_accuracy: 0.9064 - val_loss: 0.3097 - learning_rate: 1.2500e-05
# Epoch 85/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.9313 - loss: 0.1992 - val_accuracy: 0.9081 - val_loss: 0.3044 - learning_rate: 1.2500e-05
# Epoch 86/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 84s 36ms/step - accuracy: 0.9342 - loss: 0.1945 - val_accuracy: 0.9109 - val_loss: 0.3008 - learning_rate: 1.2500e-05
# Epoch 87/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 35ms/step - accuracy: 0.9344 - loss: 0.1949 - val_accuracy: 0.9087 - val_loss: 0.3060 - learning_rate: 1.2500e-05
# Epoch 88/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 85s 37ms/step - accuracy: 0.9344 - loss: 0.1948 - val_accuracy: 0.9091 - val_loss: 0.3044 - learning_rate: 1.2500e-05
# Epoch 89/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 36ms/step - accuracy: 0.9365 - loss: 0.1883 - val_accuracy: 0.9084 - val_loss: 0.3036 - learning_rate: 1.2500e-05
# Epoch 90/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.9364 - loss: 0.1899 - val_accuracy: 0.9096 - val_loss: 0.3025 - learning_rate: 1.2500e-05
# Epoch 91/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.9377 - loss: 0.1850 - val_accuracy: 0.9076 - val_loss: 0.3041 - learning_rate: 1.2500e-05
# Epoch 92/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.9384 - loss: 0.1837 - val_accuracy: 0.9072 - val_loss: 0.3059 - learning_rate: 1.2500e-05
# Epoch 93/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - accuracy: 0.9342 - loss: 0.1957 - val_accuracy: 0.9088 - val_loss: 0.2988 - learning_rate: 1.2500e-05
# Epoch 94/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 85s 37ms/step - accuracy: 0.9379 - loss: 0.1815 - val_accuracy: 0.9082 - val_loss: 0.3066 - learning_rate: 1.2500e-05
# Epoch 95/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 79s 35ms/step - accuracy: 0.9402 - loss: 0.1765 - val_accuracy: 0.9080 - val_loss: 0.3055 - learning_rate: 1.2500e-05
# Epoch 96/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.9383 - loss: 0.1824 - val_accuracy: 0.9077 - val_loss: 0.3075 - learning_rate: 1.2500e-05
# Epoch 97/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 36ms/step - accuracy: 0.9397 - loss: 0.1792 - val_accuracy: 0.9088 - val_loss: 0.3075 - learning_rate: 1.2500e-05
# Epoch 98/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 35ms/step - accuracy: 0.9388 - loss: 0.1800 - val_accuracy: 0.9126 - val_loss: 0.2970 - learning_rate: 1.2500e-05
# Epoch 99/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.9411 - loss: 0.1741 - val_accuracy: 0.9076 - val_loss: 0.3142 - learning_rate: 1.2500e-05
# Epoch 100/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 34ms/step - accuracy: 0.9409 - loss: 0.1766 - val_accuracy: 0.9078 - val_loss: 0.3076 - learning_rate: 1.2500e-05
# Epoch 101/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.9415 - loss: 0.1748 - val_accuracy: 0.9069 - val_loss: 0.3070 - learning_rate: 1.2500e-05
# Epoch 102/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - accuracy: 0.9420 - loss: 0.1692 - val_accuracy: 0.9095 - val_loss: 0.3040 - learning_rate: 1.2500e-05
# Epoch 103/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 34ms/step - accuracy: 0.9419 - loss: 0.1736 - val_accuracy: 0.9058 - val_loss: 0.3138 - learning_rate: 1.2500e-05
# Epoch 104/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 34ms/step - accuracy: 0.9422 - loss: 0.1713 - val_accuracy: 0.9065 - val_loss: 0.3139 - learning_rate: 1.2500e-05
# Epoch 105/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 36ms/step - accuracy: 0.9424 - loss: 0.1733 - val_accuracy: 0.9070 - val_loss: 0.3147 - learning_rate: 1.2500e-05
# Epoch 106/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.9419 - loss: 0.1702 - val_accuracy: 0.9102 - val_loss: 0.3016 - learning_rate: 6.2500e-06
# Epoch 107/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.9452 - loss: 0.1647 - val_accuracy: 0.9131 - val_loss: 0.2923 - learning_rate: 6.2500e-06
# Epoch 108/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 54s 34ms/step - accuracy: 0.9448 - loss: 0.1658 - val_accuracy: 0.9109 - val_loss: 0.3026 - learning_rate: 6.2500e-06
# Epoch 109/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 54s 35ms/step - accuracy: 0.9441 - loss: 0.1647 - val_accuracy: 0.9110 - val_loss: 0.2983 - learning_rate: 6.2500e-06
# Epoch 110/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 53s 34ms/step - accuracy: 0.9438 - loss: 0.1692 - val_accuracy: 0.9088 - val_loss: 0.3061 - learning_rate: 6.2500e-06
# Epoch 111/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 84s 36ms/step - accuracy: 0.9435 - loss: 0.1657 - val_accuracy: 0.9112 - val_loss: 0.3054 - learning_rate: 6.2500e-06
# Epoch 112/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.9465 - loss: 0.1600 - val_accuracy: 0.9118 - val_loss: 0.3039 - learning_rate: 6.2500e-06
# Epoch 113/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.9438 - loss: 0.1630 - val_accuracy: 0.9135 - val_loss: 0.2959 - learning_rate: 6.2500e-06
# Epoch 114/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.9458 - loss: 0.1615 - val_accuracy: 0.9129 - val_loss: 0.3005 - learning_rate: 6.2500e-06
# Epoch 115/115
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.9442 - loss: 0.1644 - val_accuracy: 0.9125 - val_loss: 0.2991 - learning_rate: 3.1250e-06

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %%
plt.title('loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
